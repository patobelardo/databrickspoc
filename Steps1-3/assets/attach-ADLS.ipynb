# %%
keyvault = "ppe-keyvault"
adlscontainer = "ppe"

configs = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": dbutils.secrets.get(scope = keyvault, key = "DataBricksClientID"), 
       "fs.azure.account.oauth2.client.secret": dbutils.secrets.get(scope = keyvault, key = "DataBricksSecret"),
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/258f1f99-ee3d-42c7-bfc5-7af1b2343e02/oauth2/token"}

dbutils.fs.mount(
source = "abfss://" + adlscontainer + "@statsconviddsinternal.dfs.core.windows.net",
mount_point = "/mnt/" + adlscontainer,
extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ExecutionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-793072835401497&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# ...

# %%
# %fs

ls "/mnt/ppe"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/ppe/incoming/</td><td>incoming/</td><td>0</td></tr></tbody></table></div>
